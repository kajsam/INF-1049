# %% [markdown]
# ### INF-1049 Assignment 1.2:
# ## Loops and lists
# ### Duedate: 30. August 2021
# ---

# %% [markdown]
# # Requirements
#
# * Read the excercise text closely, ensure that all elements of the exercise is followed in your answer
# * Comment your code such that you demonstrate an understanding of the code, if your comments are insufficient, you will not pass
# * Ensure that the code works before you hand in, solutions that do not work will not be approved
# * All excercises must be answered
# * The filename for submission must include your student ID (e.g. abc123_1_2.ipynb)

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# For the integers between 0 and 50 print out whether the it is even or odd and whether it is a divisible by 7.
#
# Example output:
#
# `...
# 7 is odd and divisible with 7.
# 8 is even and not divisible with 7.
# ...`

# %%
oddlist = [] # list for the odd
sevenlist = [] # list for sevens

for i in range(1,50): # integers between (i.e, not including) 0 and 50
     
    # i modulus 2, which is 0 if i is even, and 1 if it is odd
    if i%2: # testing if the number is odd
      # print(i, "is odd") # testing if it works
      oddlist.append("odd")
    else:
      oddlist.append("even")

    if i%7: # testing if the number is divisible by 7
        sevenlist.append(" not")
    else:
        sevenlist.append("") # empty list element

    print(str(i) + " is " + str(oddlist[i-1]) + " and" +  str(sevenlist[i-1]) + " divisible by 7.")
# Out:
# 1 is odd and not divisible by 7.
# 2 is even and not divisible by 7.
# 3 is odd and not divisible by 7.
# 4 is even and not divisible by 7.
# 5 is odd and not divisible by 7.
# 6 is even and not divisible by 7.
# 7 is odd and divisible by 7.
# 8 is even and not divisible by 7.
# 9 is odd and not divisible by 7.
# 10 is even and not divisible by 7.
# 11 is odd and not divisible by 7.
# 12 is even and not divisible by 7.
# 13 is odd and not divisible by 7.
# 14 is even and divisible by 7.
# 15 is odd and not divisible by 7.
# 16 is even and not divisible by 7.
# 17 is odd and not divisible by 7.
# 18 is even and not divisible by 7.
# 19 is odd and not divisible by 7.
# 20 is even and not divisible by 7.
# 21 is odd and divisible by 7.
# 22 is even and not divisible by 7.
# 23 is odd and not divisible by 7.
# 24 is even and not divisible by 7.
# 25 is odd and not divisible by 7.
# 26 is even and not divisible by 7.
# 27 is odd and not divisible by 7.
# 28 is even and divisible by 7.
# 29 is odd and not divisible by 7.
# 30 is even and not divisible by 7.
# 31 is odd and not divisible by 7.
# 32 is even and not divisible by 7.
# 33 is odd and not divisible by 7.
# 34 is even and not divisible by 7.
# 35 is odd and divisible by 7.
# 36 is even and not divisible by 7.
# 37 is odd and not divisible by 7.
# 38 is even and not divisible by 7.
# 39 is odd and not divisible by 7.
# 40 is even and not divisible by 7.
# 41 is odd and not divisible by 7.
# 42 is even and divisible by 7.
# 43 is odd and not divisible by 7.
# 44 is even and not divisible by 7.
# 45 is odd and not divisible by 7.
# 46 is even and not divisible by 7.
# 47 is odd and not divisible by 7.
# 48 is even and not divisible by 7.
# 49 is odd and divisible by 7.

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Compute the mathematical sum $$\sum_{k=1}^{40} \frac{\cos(k)}{\sin(k)}$$ in two ways.
#
#  1. Using a while loop
#
#  2. Using a for loop
#
# In both cases, print your answer to the screen with 2 digits after comma.

# %%
from math import cos, sin # importing the functions cos and sin from math (and nothing else)

### 1. while loop

while_sum = 0 # allocate the variable sum
k = 1 # start at 1
while k < 41: # finish at 40
    while_sum = while_sum + cos(k)/sin(k)
    # without updating, see if you can kill (real easy, it's that play button changing to a stop)
    k = k + 1

# using format to print the trailing 0's
print("1. Using a while loop, the final sum is", '{:.2f}'.format(round(while_sum, 2))) 

### 2. for loop
for_sum = 0 # allocate the variable sum
for k in range(1,41): # start at 1, finish at 40
    for_sum = for_sum + cos(k)/sin(k)

print("2. Using a for loop, the final sum is", '{:.2f}'.format(round(for_sum, 2))) 

if while_sum == for_sum:
    print("They are exactly the same!")
else:
    print("Something went wrong. Check your code!")
# Out:
# 1. Using a while loop, the final sum is 104.20
# 2. Using a for loop, the final sum is 104.20
# They are exactly the same!

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# We are given the following data
#
# | Planet| Mass[kg] |
# |-|-|
# |Mercury| 3,302$\cdot10^{23}$|
# |Venus| 4,868$\cdot10^{24}$|
# |Earth| 5,987$\cdot10^{24}$|
# |Mars| 6,418$\cdot10^{23}$|
# |Jupiter| 1,898$\cdot10^{27}$|
# |Saturn|5,684$\cdot10^{26}$|
# |Uranus| 8,684$\cdot10^{25}$|
# |Neptune| 1,025$\cdot10^{26}$|
#
# #### a)
# Make two lists, one for the planets and one for their masses.
#
# #### b)
#
# Use a for loop and zip to print out the planet and corresponding mass as shown
# > Planet: Mercury, Mass: 3.30e+23 kg
#
# #### c)
#
# Add Pluto to the planet list and its mass to the other list using append. Print out the lists.
# >The mass of Pluto is 1.30e+22 kg
#
# #### d)
# Do the following
# 1. Print "$Jupyter$" using indexing.
# 2. Print the three last and the three first planets using slicing.
# 3. Print out every second planet starting on index 0. *Hint: list[0::2]*
# 4. Delete "$Pluto$" and its corresponding mass from the lists using del and/or pop (read what/howto in the book).

# %%
#### a)
print("a)")

# Entering the planets and their masses manually
planet_list = ["Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn", "Uranus", "Neptune"]
mass_list = [3.302e+23, 4.868e+24, 5.987e+24, 6.418e+23, 1.898e+27, 5.684e+26, 8.684e+25,
1.025e+26] # e+, not 10^
if len(planet_list) != len(mass_list):
    print("The lists are of unequal length. Check your code!")

# Printing the lists and the number of element
print(len(planet_list), "planets:", planet_list)
print("List of ", len(mass_list), " masses: ", mass_list[0], ", ", mass_list[1], ",...", sep = '') # Just checking

print() # blank line (always after a subtask is finished)

#### b)
print("b)")

planet_mass = zip(planet_list, mass_list) # zipping together two lists

for elem in planet_mass: # for each element in zip
    print("Planet: ", elem[0], ", Mass: ", elem[1], " kg.", sep = '')

print()

#### c)
print("c)")

planet_list.append("Pluto") # adding "Pluto" to the end using the append function
mass_list.append(1.30e+22)

if len(planet_list) != len(mass_list): # just checking the lengths after adding elements
    print("Error, error!")
else:
    for i in range(0,len(planet_list)): # for length of planet_list
        print("The mass of ", planet_list[i], " is ", mass_list[i], " kg.", sep  = '')

# I tried looking into keeping that one trailing zero for the mass of Pluto, but it was a bit difficult since the
# other planets' masses have three digits after the dicimal point. I figured it's not all that important. 

print()

#### d)
print("d)")

### 1. 
idx = planet_list.index("Jupiter") # "Jupyter" does not exist
print("Finding Jupiter:", planet_list[idx]) # Jupiter by index

print()

### 2. 
print("Three last planets:", planet_list[-3:]) # three last 
print("Three first planets:", planet_list[:3]) # three first

print()

### 3. 

print("Every second planet:", planet_list[0::2]) # every second

print()

### 4. 

planet_list.pop() # popping Pluto
del(mass_list[-1]) # deleting its mass

print("Removing Pluto:", planet_list)
# Out:
# a)
# 8 planets: ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
# List of 8 masses: 3.302e+23, 4.868e+24,...
#
# b)
# Planet: Mercury, Mass: 3.302e+23 kg.
# Planet: Venus, Mass: 4.868e+24 kg.
# Planet: Earth, Mass: 5.987e+24 kg.
# Planet: Mars, Mass: 6.418e+23 kg.
# Planet: Jupiter, Mass: 1.898e+27 kg.
# Planet: Saturn, Mass: 5.684e+26 kg.
# Planet: Uranus, Mass: 8.684e+25 kg.
# Planet: Neptune, Mass: 1.025e+26 kg.
#
# c)
# The mass of Mercury is 3.302e+23 kg.
# The mass of Venus is 4.868e+24 kg.
# The mass of Earth is 5.987e+24 kg.
# The mass of Mars is 6.418e+23 kg.
# The mass of Jupiter is 1.898e+27 kg.
# The mass of Saturn is 5.684e+26 kg.
# The mass of Uranus is 8.684e+25 kg.
# The mass of Neptune is 1.025e+26 kg.
# The mass of Pluto is 1.3e+22 kg.
#
# d)
# Finding Jupiter: Jupiter
#
# Three last planets: ['Uranus', 'Neptune', 'Pluto']
# Three first planets: ['Mercury', 'Venus', 'Earth']
#
# Every second planet: ['Mercury', 'Earth', 'Jupiter', 'Uranus', 'Pluto']
#
# Removing Pluto: ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# `quote` is a list of strings that together form a sentence.
#
# ```python
# quote = ['Programs', 'must', 'be', 'written', 'for', 'people', \
#          'to', 'read,', 'and', 'only', 'incidentally', 'for', \
#          'machines', 'to', 'execute']
# ```
#
# 1. Iterate through `quote` and print out every word.
# 2. Iterate through `quote` and print every word with it's index.e.g.
# ```
#  0: Programs
#  1: must
#  2: be
#  ...
# ```
#
#     *Hint: The `enumerate` function might help.*
#
#     *Hint2: If you would like to learn more about how to design the output, lookup string formatting. e.g. f"{5.00:-<20.3g}".*
# 3. Iterate through `quote` and print out the number of letters in each word.
#
# 4. Iterate through `quote`, count the total number of letters in the sentence and print the result to screen.

# %%
### 1. 

quote = ['Programs', 'must', 'be', 'written', 'for', 'people', \
         'to', 'read,', 'and', 'only', 'incidentally', 'for', \
         'machines', 'to', 'execute']

# print(quote) 

for elem in quote: # for each element in list
    print(elem)
print()

### 2. 

for count, elem in enumerate(quote): # count is the iteration, I could call it 'iter' or whatever
    print(count, elem)
print()
# Out:
# Programs
# must
# be
# written
# for
# people
# to
# read,
# and
# only
# incidentally
# for
# machines
# to
# execute
#
# 0 Programs
# 1 must
# 2 be
# 3 written
# 4 for
# 5 people
# 6 to
# 7 read,
# 8 and
# 9 only
# 10 incidentally
# 11 for
# 12 machines
# 13 to
# 14 execute

# %%
### 3 
# print(quote) # why is quote suddenly only the last word of the list? It's that enumerate function
# I wrote 'for count, quote in enumerate(quote):' no wonder quote changed

for elem in quote:
    print("The number of letters in '", elem, "' is ", len(elem), sep = '')
print()
# Out:
# The number of letters in 'Programs' is 8
# The number of letters in 'must' is 4
# The number of letters in 'be' is 2
# The number of letters in 'written' is 7
# The number of letters in 'for' is 3
# The number of letters in 'people' is 6
# The number of letters in 'to' is 2
# The number of letters in 'read,' is 5
# The number of letters in 'and' is 3
# The number of letters in 'only' is 4
# The number of letters in 'incidentally' is 12
# The number of letters in 'for' is 3
# The number of letters in 'machines' is 8
# The number of letters in 'to' is 2
# The number of letters in 'execute' is 7

# %%
### 4
sum = 0
for elem in quote:
    sum = sum + len(elem)

print("The total number of letters is ", sum, ".", sep = '')
# Out:
# The total number of letters is 76.

# %% [markdown]
# ### Exercise 5

# %% [markdown]
# Below are three python structures and three tasks.
# - Structure A: for loop
# - Structure B: while loop
# - Structure C: if-else-block
#
#
#
# - Task 1: Implement a program that computes f(x) for x. Test your program with `x=6`.
# - Task 2: Implement a program that computes g(x) for all integers from 4 to 20.
# - Task 3: Implement a program that prints a value from an unordered list of unknown numbers until the first value higher than 11 is reached. Let an example list of numbers be
#     ```python
#     unordered = [3,9,7,4,54,8,6,76,12]
#     ```
#
# Formulas:
# \begin{align}
#     f(x) &=
#     \begin{cases}
#         0& , x \le 0 \\
#         x^{-0.2}& , 0 < x \le 1  \\
#         1& , 1 < x
#     \end{cases}
#     \\[1.2mm]
#     g(x) &= \sum_{k=0}^{10} \frac{(-1)^k x^{2k}}{(2k)!}
# \end{align}
#
#
# 1. Pick the most suitable python structure to solve each problem
# 2. Discribe stepwise how you would implement the three tasks.
# 3. Pick one of the tasks and complete it.
#
# *Hint: if you choose Task 2, use the `factorial` function from `math`*

# %% [markdown]
# Exercise 1.
#  <br />
# For Task 1, Structure C: if-else-block is needed. <br> <!-- Not using double space -->
#    For Task 2, Structure A: for loop is more suitable. It is a simple iteration (start, stop, even steps), and then a for loop is preferred because of the risk of being stuck in a while loop. <br>
#    For Task 3, Structure B: while loop could be more suitable, but I couldn't figure out how to iterate and test in the same go. Using a for loop here requires an extra if test.  <br>
#    <br />
# Exercise 2.
# 1. Task 1: <br>
#    1. Declare <!-- is 'declare' the right term here? -->
#    the variable x (e.g., x = 6) <br>
#    2. Test the value of x using an if ... elif .. else structure: 'if' x is non-positive, then set x to 0, 'elif' x is smaller than or equal to 1, then set x to $x^{-0.2}$, 'else' set x to 1.
#    <br />
# 2. Task 2: <br>
#    1. Set x = 4.
#    2. Set sum = 0.
#    3. Make the inner for loop using 'range' to let k run from 0 up to (not including) 11.
#    4. For each iteration, calculate the current term and add it to the current sum.
#    5. Run through the inner loop and check that it works.
#    6. Delete 'x = 4'.
#    7. Envelope the inner loop in an outer loop using 'range' to let x run from 4 up to 20. Make sure to get the indentation right.
#    <br />
# 3. Task 3: <br>
#    1. Make a for loop that runs through all the elements in the list.
#    2. Check if the current element is greater than or equal to 11, if so, print the value
#    3. If not, using 'else', break out of the for loop.

# %%
### 3 Task 3
unordered = [3,9,7,4,54,8,6,76,12] # a list

# I should not print the first element that is larger than 11. 

for count, elem in enumerate(unordered): # I count for the final check
  if elem <= 11:
    print(elem)
  else:
    break # break out

if elem <= 11 and count < len(unordered): # if elem is still <= 11, and we haven't reached the end of the list
  print("You're logic is illogical!")
# Out:
# 3
# 9
# 7
# 4

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# 1. Use a list comprehension to generate a list of values with the expression $E(e) = e/3$ where the range varies in the interval (-6, 6).
#
# 1. Use another list comprehension to generate a list of $f(x)$ values for the function
# $$f(x) = \frac{a}{x+6} - b$$
# when $a = 100$ and $b = 2$. The range of $x$ should be the list generated in 1.
#
# 1. Print the sentence *"The value $x=x_i$ corresponds to the value $y=f(x_i)$ relative to the function $f(x)$."* for all corresponding values $(x_i, f(x_i))$ in the lists from 1 and 2.
#
#     *Hint: the zip-command discussed in section 2.3.6 may come in handy here.*
#
# 1. Store the value pairs $(x_i, f(x_i))$ from task 1 and 2 in a nested list on the form $[[x_0, y_0],[x_1,y_1]\dots[x_i, y_i]]$. Print the nested list to the screen.
#
# 1. Iterate over the nested list from 4 and generate a new nested list on the form $[[x_0, x_1, ...], [y_0, y_1, ...]]$.

# %%
### 1. Comprehended list

elist = [e/3 for e in range(-6,6)]

elist_round = [round(elem, 2) for elem in elist] # round to make a nice print
print("1. The list:", elist_round)

### 2. Another comprehended list

a = 100
b = 2
flist = [a/(x+6)-b for x in elist]
flist_round = [round(elem, 2) for elem in flist] # round to make a nice print
print("2. The other list:", flist_round)

### 3. Zipping elist and flist 

zlist = zip(elist, flist) # this is not a list?

print("3. Type:", type(zlist)) # no, it's a zip

for elem in zlist:
    print("The value x =", '{:.2f}'.format(round(elem[0], 2)), 
    "corresponds to the value y =", '{:.2f}'.format(round(elem[1], 2)), 
    "relative to the function f(x).")
print()

################################
# I still don't understand a lot of things
print(zlist)
print("Do it again.")

for elem in zlist: # why is this not workin any more?
    print(elem[0])

print("why this not working?")
# The explanation seems to be that by iterating through zlist (which is not a list), I've spent it all.

print()

###############################


### 4. Nested list
# print(elist)
# print(flist)

nlist = []

for i in range(0,len(elist)):
    nlist.append([elist[i],flist[i]])

# nlist_round = [round(elem, 2) for elem in nlist] # round to make a nice print
# this didn't work, seems to be because elem now is a list?
print("Type elem:", type(elem)) # it's not a list, it's a tuple

import numpy as np # this a suggestion from stack overflow
nlist_round = list(np.around(np.array(nlist),2)) # but then it's not a list anymore?

print("Type nlist_round:", type(nlist_round))

print("4. Nested list:", nlist_round) # is ugly still
print("It's length:", len(nlist))
print("Accessing element (0,1):", nlist[0][1])

print()

### 5. Another nested list

anlist = []

anlist.append([nlist[i][0] for i in range(0,len(nlist))])
anlist.append([nlist[i][1] for i in range(0,len(nlist))])

anlist_round = list(np.around(np.array(anlist),2))
print("5. Another nested list:", anlist_round)
# Out:
# 1. The list: [-2.0, -1.67, -1.33, -1.0, -0.67, -0.33, 0.0, 0.33, 0.67, 1.0, 1.33, 1.67]
# 2. The other list: [23.0, 21.08, 19.43, 18.0, 16.75, 15.65, 14.67, 13.79, 13.0, 12.29, 11.64, 11.04]
# 3. Type: <class 'zip'>
# The value x = -2.00 corresponds to the value y = 23.00 relative to the function f(x).
# The value x = -1.67 corresponds to the value y = 21.08 relative to the function f(x).
# The value x = -1.33 corresponds to the value y = 19.43 relative to the function f(x).
# The value x = -1.00 corresponds to the value y = 18.00 relative to the function f(x).
# The value x = -0.67 corresponds to the value y = 16.75 relative to the function f(x).
# The value x = -0.33 corresponds to the value y = 15.65 relative to the function f(x).
# The value x = 0.00 corresponds to the value y = 14.67 relative to the function f(x).
# The value x = 0.33 corresponds to the value y = 13.79 relative to the function f(x).
# The value x = 0.67 corresponds to the value y = 13.00 relative to the function f(x).
# The value x = 1.00 corresponds to the value y = 12.29 relative to the function f(x).
# The value x = 1.33 corresponds to the value y = 11.64 relative to the function f(x).
# The value x = 1.67 corresponds to the value y = 11.04 relative to the function f(x).
#
# <zip object at 0x7fed3717c6c0>
# Do it again.
# why this not working?
#
# Type elem: <class 'tuple'>
# Type nlist_round: <class 'list'>
# 4. Nested list: [array([-2., 23.]), array([-1.67, 21.08]), array([-1.33, 19.43]), array([-1., 18.]), array([-0.67, 16.75]), array([-0.33, 15.65]), array([ 0.  , 14.67]), array([ 0.33, 13.79]), array([ 0.67, 13.  ]), array([ 1.  , 12.29]), array([ 1.33, 11.64]), array([ 1.67, 11.04])]
# It's length: 12
# Accessing element (0,1): 23.0
#
# 5. Another nested list: [array([-2.  , -1.67, -1.33, -1.  , -0.67, -0.33,  0.  ,  0.33,  0.67,
#         1.  ,  1.33,  1.67]), array([23.  , 21.08, 19.43, 18.  , 16.75, 15.65, 14.67, 13.79, 13.  ,
#        12.29, 11.64, 11.04])]
